# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from pandas import read_csv

# %%
df = read_csv("C:\\Users\\Lenovo\\Downloads\\winequality-white.csv", sep =';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# # Understand the data using the pandas library

# %% [markdown]
# 1.Print the first five rows of the dataset

# %%
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# 2.Print the last five rows of the dataset

# %%
df.tail(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# ...

# %% [markdown]
# 3.Find out the total number of rows and columns of the data set

# %% [markdown]
# There are 4898 rows and 12 columns

# %% [markdown]
# 4.Find out the columns, data types, and presence of null values or missing values in the data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# 1.Find out missing values graphically

# %%
sns.countplot(x = df["fixed acidity"])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='count'>

# %%
sns.countplot(x = df["volatile acidity"])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='count'>

# %%
sns.countplot(x = df["citric acid"])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='count'>

# %%
sns.countplot(x = df["residual sugar"])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='count'>

# %%
sns.countplot(x = df["chlorides"])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='count'>

# %%
sns.countplot(x = df["free sulfur dioxide"])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='count'>

# %%
sns.countplot(x = df["total sulfur dioxide"])
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='count'>

# %%
sns.countplot(x = df["density"])
# Out:
# <AxesSubplot:xlabel='density', ylabel='count'>

# %%
sns.countplot(x = df["pH"])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='count'>

# %%
sns.countplot(x = df["sulphates"])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='count'>

# %%
sns.countplot(x = df["alcohol"])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='count'>

# %%
sns.countplot(x = df["quality"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# 2.Find out the number of rows, mean, std deviation, min, Q1, Q2, Q3, max values for each variable.
# Document your observations to check if the outliers are present in the data set

# %%
round(df.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count         4898.0            4898.0       4898.0          4898.0
# mean             7.0               0.0          0.0             6.0
# std              1.0               0.0          0.0             5.0
# min              4.0               0.0          0.0             1.0
# 25%              6.0               0.0          0.0             2.0
# 50%              7.0               0.0          0.0             5.0
# 75%              7.0               0.0          0.0            10.0
# max             14.0               1.0          2.0            66.0
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density      pH  \
# count     4898.0               4898.0                4898.0   4898.0  4898.0
# mean         0.0                 35.0                 138.0      1.0     3.0
# std          0.0                 17.0                  42.0      0.0     0.0
# ...

# %% [markdown]
# 3.Draw the histogram, kernel density estimate (kde) to check the distribution and skewness for each variable.
# Document your observation

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
print(sns.kdeplot(data = df["fixed acidity"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.kdeplot(data = df["volatile acidity"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.kdeplot(data = df["citric acid"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.kdeplot(data = df["residual sugar"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.kdeplot(data = df["chlorides"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.kdeplot(data = df["free sulfur dioxide"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.kdeplot(data = df["total sulfur dioxide"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.kdeplot(data = df["density"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.kdeplot(data = df["pH"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.kdeplot(data = df["sulphates"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.kdeplot(data = df["alcohol"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.kdeplot(data = df["quality"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
sns.distplot(df)
# Out:
# E:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
df.hist(bins =50,figsize = (15,15))
# Out:
# array([[<AxesSubplot:title={'center':'fixed acidity'}>,
#         <AxesSubplot:title={'center':'volatile acidity'}>,
#         <AxesSubplot:title={'center':'citric acid'}>],
#        [<AxesSubplot:title={'center':'residual sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free sulfur dioxide'}>],
#        [<AxesSubplot:title={'center':'total sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>],
#        [<AxesSubplot:title={'center':'sulphates'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %% [markdown]
# 4.Create a frequency distribution table and bar chart for the output variable

# %%
print("Frequency Table for quality")
quality = pd.crosstab(index=df['quality'],columns='count')
print(quality)
quality.plot.bar(figsize = (10,5))
# Out:
# Frequency Table for quality
# col_0    count
# quality
# 3           20
# 4          163
# 5         1457
# 6         2198
# 7          880
# 8          175
# 9            5
# <AxesSubplot:xlabel='quality'>

# %%
df.plot.bar(figsize = (10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# 5.Draw box plot for each variable and identify the IQR and outliers

# %%
boxplot = df.boxplot(column = ['fixed acidity'])
plt.show()

# %%
from numpy import percentile

# %%
quartiles = percentile(df["fixed acidity"], [25,50,75])
dmin,dmax = df["fixed acidity"].min(),df["fixed acidity"].max()

# %%
print("Min :", dmin)
print("Quartile Q1 :", quartiles[0])
print("Quartile Q2:", quartiles[1])
print("Quartile Q3:", quartiles[2])
print("Max :", dmax)
# Out:
# Min : 3.8
# Quartile Q1 : 6.3
# Quartile Q2: 6.8
# Quartile Q3: 7.3
# Max : 14.2

# %%
iqr = quartiles[2]- quartiles[0]
print("Interquartile range:", iqr)
# Out:
# Interquartile range: 1.0

# %%
boxplot = df.boxplot(column = ['volatile acidity'])
plt.show()

# %%
quartiles = percentile(df["volatile acidity"], [25,50,75])
dmin,dmax = df["volatile acidity"].min(),df["volatile acidity"].max()

# %%
print("Min :", dmin)
print("Quartile Q1 :", quartiles[0])
print("Quartile Q2:", quartiles[1])
print("Quartile Q3:", quartiles[2])
print("Max :", dmax)
# Out:
# Min : 0.08
# Quartile Q1 : 0.21
# Quartile Q2: 0.26
# Quartile Q3: 0.32
# Max : 1.1

# %%
iqr = quartiles[2]- quartiles[0]
print("Interquartile range:", iqr)
# Out:
# Interquartile range: 0.11000000000000001

# %%
boxplot = df.boxplot(column = ['citric acid'])
plt.show()

# %%
quartiles = percentile(df["citric acid"], [25,50,75])
dmin,dmax = df["citric acid"].min(), df["citric acid"].max()

# %%
print("Min :", dmin)
print("Quartiles Q1:", quartiles[0])
print("Quartiles Q2 :",quartiles[1])
print("Quartiles Q3 :", quartiles[2] )
print("Max :", dmax)
# Out:
# Min : 65.8
# Quartiles Q1: 1.7
# Quartiles Q2 : 5.2
# Quartiles Q3 : 9.9
# Max : 0.6

# %%
iqr = quartiles[2]- quartiles[0]
print("Interquartile range", iqr)
# Out:
# Interquartile range 8.200000000000001

# %%
boxplot = df.boxplot(column = ['residual sugar'])
plt.show()

# %%
quartiles = percentile(df["residual sugar"],[25,50,75])
dmax, dmin = df["residual sugar"].min(),df["residual sugar"].max()

# %%
print("Min :", dmin)
print("Quartile Q1:", quartiles[0])
print("Quartile Q2:", quartiles[1])
print("Quartile Q3:", quartiles[2])
print("Max :", dmax)
# Out:
# Min : 65.8
# Quartile Q1: 1.7
# Quartile Q2: 5.2
# Quartile Q3: 9.9
# Max : 0.6

# %%
iqr = quartiles[2] - quartiles[0]
print("Interquartile range:", iqr)
# Out:
# Interquartile range: 8.200000000000001

# %%
boxplot = df.boxplot(column = ['chlorides'])
plt.show()

# %%
quartiles = percentile(df["chlorides"],[25,50,75])
dmax, dmin = df["chlorides"].min(),df["chlorides"].max()

# %%
print("Min :", dmin)
print("Quartile Q1:", quartiles[0])
print("Quartile Q2:", quartiles[1])
print("Quartile Q3:", quartiles[2])
print("Max :", dmax)
# Out:
# Min : 0.34600000000000003
# Quartile Q1: 0.036000000000000004
# Quartile Q2: 0.043
# Quartile Q3: 0.05
# Max : 0.009000000000000001

# %%
iqr = quartiles[2] - quartiles[0]
print("Interquartile range:", iqr)
# Out:
# Interquartile range: 0.013999999999999999

# %%
boxplot = df.boxplot(column = ['free sulfur dioxide'])
plt.show()

# %%
quartiles = percentile(df["free sulfur dioxide"],[25,50,75])
dmax, dmin = df["free sulfur dioxide"].min(),df["free sulfur dioxide"].max()

# %%
print("Min :", dmin)
print("Quartile Q1:", quartiles[0])
print("Quartile Q2:", quartiles[1])
print("Quartile Q3:", quartiles[2])
print("Max :", dmax)
# Out:
# Min : 289.0
# Quartile Q1: 23.0
# Quartile Q2: 34.0
# Quartile Q3: 46.0
# Max : 2.0

# %%
iqr = quartiles[2]- quartiles[0]
print("Interquartile range:", iqr)
# Out:
# Interquartile range: 23.0

# %%
boxplot = df.boxplot(column = ['total sulfur dioxide'])
plt.show()

# %%
quartiles = percentile(df["total sulfur dioxide"],[25,50,75])
dmax, dmin = df["total sulfur dioxide"].min(),df["total sulfur dioxide"].max()

# %%
print("Min :", dmin)
print("Quartile Q1:", quartiles[0])
print("Quartile Q2:", quartiles[1])
print("Quartile Q3:", quartiles[2])
print("Max :", dmax)
# Out:
# Min : 440.0
# Quartile Q1: 108.0
# Quartile Q2: 134.0
# Quartile Q3: 167.0
# Max : 9.0

# %%
iqr = quartiles[2]- quartiles[0]
print("Interquartile range:", iqr)
# Out:
# Interquartile range: 59.0

# %%
boxplot = df.boxplot(column = ['density'])
plt.show()

# %%
quartiles = percentile(df["density"],[25,50,75])
dmax, dmin = df["density"].min(),df["density"].max()

# %%
print("Min :", dmin)
print("Quartile Q1:", quartiles[0])
print("Quartile Q2:", quartiles[1])
print("Quartile Q3:", quartiles[2])
print("Max :", dmax)
# Out:
# Min : 1.03898
# Quartile Q1: 0.9917225000000001
# Quartile Q2: 0.99374
# Quartile Q3: 0.9961
# Max : 0.98711

# %%
iqr = quartiles[2]- quartiles[0]
print("Interquartile range:", iqr)
# Out:
# Interquartile range: 0.004377499999999923

# %%
boxplot = df.boxplot(column = ['pH'])
plt.show()

# %%
quartiles = percentile(df["pH"],[25,50,75])
dmax, dmin = df["pH"].min(),df["pH"].max()

# %%
print("Min :", dmin)
print("Quartile Q1:", quartiles[0])
print("Quartile Q2:", quartiles[1])
print("Quartile Q3:", quartiles[2])
print("Max :", dmax)
# Out:
# Min : 3.82
# Quartile Q1: 3.09
# Quartile Q2: 3.18
# Quartile Q3: 3.28
# Max : 2.72

# %%
iqr = quartiles[2]- quartiles[0]
print("Interquartile range:", iqr)
# Out:
# Interquartile range: 0.18999999999999995

# %%
boxplot = df.boxplot(column = ['sulphates'])
plt.show()

# %%
quartiles = percentile(df["sulphates"],[25,50,75])
dmax, dmin = df["sulphates"].min(),df["sulphates"].max()

# %%
print("Min :", dmin)
print("Quartile Q1:", quartiles[0])
print("Quartile Q2:", quartiles[1])
print("Quartile Q3:", quartiles[2])
print("Max :", dmax)
# Out:
# Min : 1.08
# Quartile Q1: 0.41
# Quartile Q2: 0.47
# Quartile Q3: 0.55
# Max : 0.22

# %%
iqr = quartiles[2]- quartiles[0]
print("Interquartile range:", iqr)
# Out:
# Interquartile range: 0.14000000000000007

# %%
boxplot = df.boxplot(column = ['alcohol'])
plt.show()

# %%
quartiles = percentile(df["alcohol"],[25,50,75])
dmax, dmin = df["alcohol"].min(),df["alcohol"].max()

# %%
print("Min :", dmin)
print("Quartile Q1:", quartiles[0])
print("Quartile Q2:", quartiles[1])
print("Quartile Q3:", quartiles[2])
print("Max :", dmax)
# Out:
# Min : 14.2
# Quartile Q1: 9.5
# Quartile Q2: 10.4
# Quartile Q3: 11.4
# Max : 8.0

# %%
iqr = quartiles[2]- quartiles[0]
print("Interquartile range:", iqr)
# Out:
# Interquartile range: 1.9000000000000004

# %%
boxplot = df.boxplot(column = ['quality'])
plt.show()

# %%
quartiles = percentile(df["quality"],[25,50,75])
dmax, dmin = df["quality"].min(),df["quality"].max()

# %%
print("Min :", dmin)
print("Quartile Q1:", quartiles[0])
print("Quartile Q2:", quartiles[1])
print("Quartile Q3:", quartiles[2])
print("Max :", dmax)
# Out:
# Min : 9
# Quartile Q1: 5.0
# Quartile Q2: 6.0
# Quartile Q3: 6.0
# Max : 3

# %%
iqr = quartiles[2]- quartiles[0]
print("Interquartile range:", iqr)
# Out:
# Interquartile range: 1.0

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# 1. Draw the correlation matrix and identify the variables that are correlated to each other.

# %%
myrel = sns.heatmap(df.corr(), annot = True)
